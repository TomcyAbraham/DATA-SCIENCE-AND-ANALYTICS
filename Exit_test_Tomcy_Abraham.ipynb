# %% [markdown]
# **IMPORTING BASIC LIBRARIES**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **IMPORTING THE DATASET**

# %% [markdown]
# our dataset will be called "df"

# %%
df=pd.read_csv('/content/Employee.csv')

# %% [markdown]
# **Analysing the dataset**

# %% [markdown]
# invoking head and tail

# %%
df.head()
# Out:
#    Employee ID  Age  Gender  Years at Company    Job Role  Monthly Income  \
# 0         8410   31    Male                19   Education            5390
# 1        64756   59  Female                 4       Media            5534
# 2        30257   24  Female                10  Healthcare            8159
# 3        65791   36  Female                 7   Education            3989
# 4        65026   56    Male                41   Education            4821
#
#   Work-Life Balance Job Satisfaction Performance Rating  Number of Promotions  \
# 0         Excellent           Medium            Average                   2.0
# 1              Poor             High                Low                   3.0
# 2              Good             High                Low                   0.0
# 3              Good             High               High                   1.0
# 4              Fair        Very High            Average                   0.0
#
#    ... Number of Dependents  Job Level Company Size Company Tenure  \
# 0  ...                  0.0        Mid       Medium             89
# 1  ...                  3.0        Mid       Medium             21
# 2  ...                  3.0        Mid       Medium             74
# 3  ...                  2.0        Mid        Small             50
# 4  ...                  0.0     Senior       Medium             68
#
#    Remote Work Leadership Opportunities Innovation Opportunities  \
# 0           No                       No                       No
# 1           No                       No                       No
# 2           No                       No                       No
# 3          Yes                       No                       No
# 4           No                       No                       No
#
#    Company Reputation Employee Recognition Attrition
# 0           Excellent               Medium    Stayed
# 1                Fair                  Low    Stayed
# 2                Poor                  Low    Stayed
# 3                Good               Medium    Stayed
# 4                Fair               Medium    Stayed
#
# [5 rows x 24 columns]

# %%
df.tail()
# Out:
#        Employee ID  Age  Gender  Years at Company    Job Role  Monthly Income  \
# 74493        16243   56  Female                42  Healthcare            7830
# 74494        47175   30  Female                15   Education            3856
# 74495        12409   52    Male                 5   Education            5654
# 74496         9554   18    Male                 4   Education            5276
# 74497        73042   59  Female                48   Education            3774
#
#       Work-Life Balance Job Satisfaction Performance Rating  \
# 74493              Poor           Medium            Average
# 74494              Good           Medium            Average
# 74495              Good        Very High      Below Average
# 74496              Fair             High            Average
# 74497              Good             High      Below Average
#
#        Number of Promotions  ... Number of Dependents  Job Level Company Size  \
# 74493                   0.0  ...                  0.0     Senior       Medium
# 74494                   2.0  ...                  0.0      Entry       Medium
# 74495                   0.0  ...                  4.0        Mid        Small
# 74496                   0.0  ...                  3.0        Mid        Large
# 74497                   1.0  ...                  4.0        Mid        Large
#
#       Company Tenure  Remote Work Leadership Opportunities  \
# 74493             60           No                       No
# 74494             20           No                       No
# 74495              7           No                       No
# 74496              5           No                       No
# 74497            118           No                       No
#
#       Innovation Opportunities  Company Reputation Employee Recognition  \
# 74493                       No                Poor               Medium
# 74494                       No                Good               Medium
# 74495                       No                Good                 High
# 74496                       No                Poor                 High
# 74497                       No                Good            Very High
#
#       Attrition
# 74493    Stayed
# 74494      Left
# 74495      Left
# 74496    Stayed
# 74497      Left
#
# [5 rows x 24 columns]

# %% [markdown]
# **DATA UNDERSTANDING AND EDA**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74498 entries, 0 to 74497
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Employee ID               74498 non-null  int64
#  1   Age                       74498 non-null  int64
#  2   Gender                    74498 non-null  object
#  3   Years at Company          74498 non-null  int64
#  4   Job Role                  74498 non-null  object
#  5   Monthly Income            74498 non-null  int64
#  6   Work-Life Balance         74494 non-null  object
#  7   Job Satisfaction          74498 non-null  object
#  8   Performance Rating        74494 non-null  object
#  9   Number of Promotions      74493 non-null  float64
#  10  Overtime                  74498 non-null  object
#  11  Distance from Home        74498 non-null  int64
#  12  Education Level           74493 non-null  object
#  13  Marital Status            74494 non-null  object
#  14  Number of Dependents      74492 non-null  float64
#  15  Job Level                 74493 non-null  object
#  16  Company Size              74496 non-null  object
#  17  Company Tenure            74498 non-null  int64
#  18  Remote Work               74495 non-null  object
#  19  Leadership Opportunities  74498 non-null  object
#  20  Innovation Opportunities  74498 non-null  object
#  21  Company Reputation        74498 non-null  object
#  22  Employee Recognition      74496 non-null  object
#  23  Attrition                 74498 non-null  object
# dtypes: float64(2), int64(6), object(16)
# memory usage: 13.6+ MB

# %% [markdown]
# our data contains integer,float and object datatypes

# %%
df.describe()
# Out:
#         Employee ID           Age  Years at Company  Monthly Income  \
# count  74498.000000  74498.000000      74498.000000    74498.000000
# mean   37249.500000     38.529746         15.721603     7299.379514
# std    21505.864514     12.083456         11.223744     2152.508566
# min        1.000000     18.000000          1.000000     1226.000000
# 25%    18625.250000     28.000000          7.000000     5652.000000
# 50%    37249.500000     39.000000         13.000000     7348.000000
# 75%    55873.750000     49.000000         23.000000     8876.000000
# max    74498.000000     59.000000         51.000000    16149.000000
#
#        Number of Promotions  Distance from Home  Number of Dependents  \
# count          74493.000000        74498.000000          74492.000000
# mean               0.832978           49.991584              1.650365
# std                0.995303           28.513611              1.553660
# min                0.000000            1.000000              0.000000
# 25%                0.000000           25.000000              0.000000
# 50%                1.000000           50.000000              1.000000
# 75%                2.000000           75.000000              3.000000
# max                4.000000           99.000000              6.000000
#
#        Company Tenure
# count    74498.000000
# mean        55.727456
# std         25.399349
# min          2.000000
# 25%         36.000000
# 50%         56.000000
# 75%         76.000000
# max        128.000000

# %% [markdown]
# **Checking For Null Values**

# %%
df.isna().sum()
# Out:
# Employee ID                 0
# Age                         0
# Gender                      0
# Years at Company            0
# Job Role                    0
# Monthly Income              0
# Work-Life Balance           4
# Job Satisfaction            0
# Performance Rating          4
# Number of Promotions        5
# Overtime                    0
# Distance from Home          0
# Education Level             5
# Marital Status              4
# Number of Dependents        6
# Job Level                   5
# Company Size                2
# Company Tenure              0
# Remote Work                 3
# Leadership Opportunities    0
# Innovation Opportunities    0
# Company Reputation          0
# Employee Recognition        2
# Attrition                   0
# dtype: int64

# %% [markdown]
# 10 columns has null values

# %%
df.columns
# Out:
# Index(['Employee ID', 'Age', 'Gender', 'Years at Company', 'Job Role',
#        'Monthly Income', 'Work-Life Balance', 'Job Satisfaction',
#        'Performance Rating', 'Number of Promotions', 'Overtime',
#        'Distance from Home', 'Education Level', 'Marital Status',
#        'Number of Dependents', 'Job Level', 'Company Size', 'Company Tenure',
#        'Remote Work', 'Leadership Opportunities', 'Innovation Opportunities',
#        'Company Reputation', 'Employee Recognition', 'Attrition'],
#       dtype='object')

# %% [markdown]
# **Data PreProcessing**

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Number of Dependents        6
# Education Level             5
# Number of Promotions        5
# Job Level                   5
# Work-Life Balance           4
# Performance Rating          4
# Marital Status              4
# Remote Work                 3
# Employee Recognition        2
# Company Size                2
# Company Reputation          0
# Innovation Opportunities    0
# Leadership Opportunities    0
# Company Tenure              0
# Employee ID                 0
# Age                         0
# Distance from Home          0
# Overtime                    0
# Job Satisfaction            0
# Monthly Income              0
# Job Role                    0
# Years at Company            0
# Gender                      0
# Attrition                   0
# dtype: int64

# %%
fregraph=df.select_dtypes(include=['float'])
fregraph.hist(figsize=(20,15))
plt.show()

# %% [markdown]
# since the 2 columns are skewed we use median to fill null values

# %%
df['Number of Dependents']=df['Number of Dependents'].fillna(df['Number of Dependents'].median())
df['Number of Promotions']=df['Number of Promotions'].fillna(df['Number of Promotions'].median())

# %% [markdown]
# all object columns which have null values are stored in a new_col and using mode to fill the null values

# %%
new_col=['Education Level','Job Level','Work-Life Balance','Performance Rating','Marital Status','Remote Work','Employee Recognition','Company Size']

# %%
for i in new_col:
  df[i]=df[i].fillna(df[i].mode()[0])

# %%
df.isna().sum()
# Out:
# Employee ID                 0
# Age                         0
# Gender                      0
# Years at Company            0
# Job Role                    0
# Monthly Income              0
# Work-Life Balance           0
# Job Satisfaction            0
# Performance Rating          0
# Number of Promotions        0
# Overtime                    0
# Distance from Home          0
# Education Level             0
# Marital Status              0
# Number of Dependents        0
# Job Level                   0
# Company Size                0
# Company Tenure              0
# Remote Work                 0
# Leadership Opportunities    0
# Innovation Opportunities    0
# Company Reputation          0
# Employee Recognition        0
# Attrition                   0
# dtype: int64

# %% [markdown]
# all null values are removed

# %%
df.head()
# Out:
#    Employee ID  Age  Gender  Years at Company    Job Role  Monthly Income  \
# 0         8410   31    Male                19   Education            5390
# 1        64756   59  Female                 4       Media            5534
# 2        30257   24  Female                10  Healthcare            8159
# 3        65791   36  Female                 7   Education            3989
# 4        65026   56    Male                41   Education            4821
#
#   Work-Life Balance Job Satisfaction Performance Rating  Number of Promotions  \
# 0         Excellent           Medium            Average                   2.0
# 1              Poor             High                Low                   3.0
# 2              Good             High                Low                   0.0
# 3              Good             High               High                   1.0
# 4              Fair        Very High            Average                   0.0
#
#    ... Number of Dependents  Job Level Company Size Company Tenure  \
# 0  ...                  0.0        Mid       Medium             89
# 1  ...                  3.0        Mid       Medium             21
# 2  ...                  3.0        Mid       Medium             74
# 3  ...                  2.0        Mid        Small             50
# 4  ...                  0.0     Senior       Medium             68
#
#    Remote Work Leadership Opportunities Innovation Opportunities  \
# 0           No                       No                       No
# 1           No                       No                       No
# 2           No                       No                       No
# 3          Yes                       No                       No
# 4           No                       No                       No
#
#    Company Reputation Employee Recognition Attrition
# 0           Excellent               Medium    Stayed
# 1                Fair                  Low    Stayed
# 2                Poor                  Low    Stayed
# 3                Good               Medium    Stayed
# 4                Fair               Medium    Stayed
#
# [5 rows x 24 columns]

# %% [markdown]
# **OUTLIER DETECTION**

# %%
num_col = df.select_dtypes(include=['float', 'int'])
for i in num_col:
    plt.figure()
    sns.boxplot(df[i])

# %% [markdown]
# 2 columns have outliers

# %%
outlier_col=['Monthly Income','Years at Company']

# %% [markdown]
# removing outliers using IQR method

# %%
for j in outlier_col:
    Q1=np.percentile(df[j],25,method='midpoint')
    Q2=np.percentile(df[j],50,method='midpoint')
    Q3=np.percentile(df[j],75,method='midpoint')
    IQR = Q3-Q1
    low_lim = Q1-1.5*IQR
    up_lim = Q3+1.5*IQR
    outliers = []
    for h in df[j]:
        if ((h < low_lim) | (h > up_lim)):
            outliers.append(h)
    df[j]=df[j].clip(lower=low_lim,upper=up_lim)

# %%
for i in outlier_col:
    plt.figure()
    sns.boxplot(df[i])

# %% [markdown]
# Encoding

# %%
obj_col=df.select_dtypes(include=['object'])

# %% [markdown]
# **Label Encoding**

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
for i in obj_col:
    df[i]=le.fit_transform(df[i])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74498 entries, 0 to 74497
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Employee ID               74498 non-null  int64
#  1   Age                       74498 non-null  int64
#  2   Gender                    74498 non-null  int64
#  3   Years at Company          74498 non-null  int64
#  4   Job Role                  74498 non-null  int64
#  5   Monthly Income            74498 non-null  int64
#  6   Work-Life Balance         74498 non-null  int64
#  7   Job Satisfaction          74498 non-null  int64
#  8   Performance Rating        74498 non-null  int64
#  9   Number of Promotions      74498 non-null  float64
#  10  Overtime                  74498 non-null  int64
#  11  Distance from Home        74498 non-null  int64
#  12  Education Level           74498 non-null  int64
#  13  Marital Status            74498 non-null  int64
#  14  Number of Dependents      74498 non-null  float64
#  15  Job Level                 74498 non-null  int64
#  16  Company Size              74498 non-null  int64
#  17  Company Tenure            74498 non-null  int64
#  18  Remote Work               74498 non-null  int64
#  19  Leadership Opportunities  74498 non-null  int64
#  20  Innovation Opportunities  74498 non-null  int64
#  21  Company Reputation        74498 non-null  int64
#  22  Employee Recognition      74498 non-null  int64
#  23  Attrition                 74498 non-null  int64
# dtypes: float64(2), int64(22)
# memory usage: 13.6 MB

# %% [markdown]
# Target column Value counts

# %%
df['Attrition'].value_counts()
# Out:
# Attrition
# 1    39128
# 0    35370
# Name: count, dtype: int64

# %% [markdown]
# **CORRELATION**

# %%
plt.figure(figsize=(24,20))
cmap = sns.diverging_palette(220, 10, center='light', as_cmap=True)
sns.heatmap(data = df.corr(),annot=True,cmap=cmap)
# Out:
# <Axes: >

# %% [markdown]
# No correlation found

# %% [markdown]
# **Feature reduction**

# %%
df.drop(['Employee ID'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Age  Gender  Years at Company  Job Role  Monthly Income  Work-Life Balance  \
# 0   31       1                19         0            5390                  0
# 1   59       0                 4         3            5534                  3
# 2   24       0                10         2            8159                  2
# 3   36       0                 7         0            3989                  2
# 4   56       1                41         0            4821                  1
#
#    Job Satisfaction  Performance Rating  Number of Promotions  Overtime  ...  \
# 0                 2                   0                   2.0         0  ...
# 1                 0                   3                   3.0         0  ...
# 2                 0                   3                   0.0         0  ...
# 3                 0                   2                   1.0         0  ...
# 4                 3                   0                   0.0         1  ...
#
#    Number of Dependents  Job Level  Company Size  Company Tenure  Remote Work  \
# 0                   0.0          1             1              89            0
# 1                   3.0          1             1              21            0
# 2                   3.0          1             1              74            0
# 3                   2.0          1             2              50            1
# 4                   0.0          2             1              68            0
#
#    Leadership Opportunities  Innovation Opportunities  Company Reputation  \
# 0                         0                         0                   0
# 1                         0                         0                   1
# 2                         0                         0                   3
# 3                         0                         0                   2
# 4                         0                         0                   1
#
#    Employee Recognition  Attrition
# 0                     2          1
# 1                     1          1
# 2                     1          1
# 3                     2          1
# 4                     2          1
#
# [5 rows x 23 columns]

# %%
X=df.drop(['Attrition'],axis=1)
y=df['Attrition']

# %% [markdown]
# **Importing train test split for modelling**

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42,test_size=0.2)

# %% [markdown]
# Importing various scores to check the accuracy of model

# %%
from sklearn.metrics import accuracy_score,confusion_matrix, precision_score, recall_score, f1_score

# %% [markdown]
# **LOGISTIC REGGRESSION**

# %%
from sklearn.linear_model import LogisticRegression
logistic_reg = LogisticRegression(max_iter=1000)
logistic_reg.fit(X_train, y_train)
logistic_reg_pred = logistic_reg.predict(X_test)
logistic_reg_accuracy = accuracy_score(y_test, logistic_reg_pred)
logistic_precision = precision_score(y_test, logistic_reg_pred, average='macro')
logistic_recall = recall_score(y_test, logistic_reg_pred, average='macro')
logistic_f1 = f1_score(y_test, logistic_reg_pred, average='macro')
print("logistic_reg_accuracy:", logistic_reg_accuracy)
print("confusion_matrix:", confusion_matrix(y_test,logistic_reg_pred))
print("precision_score:",logistic_precision)
print("recall_score:",logistic_recall)
print("f1_score:",logistic_f1)
# Out:
# logistic_reg_accuracy: 0.7122147651006712
# confusion_matrix: [[4920 2176]
#  [2112 5692]]
# precision_score: 0.7115477043573919
# recall_score: 0.7113589596755227
# f1_score: 0.7114401285237517

# %% [markdown]
# **DECISION TREE CLASSIFIER**

# %%
from sklearn.tree import DecisionTreeClassifier
decision_tree = DecisionTreeClassifier()
decision_tree.fit(X_train, y_train)
decision_tree_pred = decision_tree.predict(X_test)
decision_tree_accuracy = accuracy_score(y_test, decision_tree_pred)
decision_tree_precision = precision_score(y_test, decision_tree_pred, average='macro')
decision_tree_recall = recall_score(y_test, decision_tree_pred, average='macro')
decision_tree_f1 = f1_score(y_test, decision_tree_pred, average='macro')
print("Decision Tree Accuracy:", decision_tree_accuracy)

print("precision_score:",decision_tree_precision)
print("recall_score:",decision_tree_recall)
print("f1_score:",decision_tree_f1)
# Out:
# Decision Tree Accuracy: 0.6739597315436242
# precision_score: 0.6732105868631835
# recall_score: 0.6731835623855484
# f1_score: 0.6731966358995105

# %% [markdown]
# **RANDOM FOREST CLASSIFIER**

# %%
from sklearn.ensemble import RandomForestClassifier
random_forest = RandomForestClassifier()
random_forest.fit(X_train, y_train)
random_forest_pred = random_forest.predict(X_test)
random_forest_accuracy = accuracy_score(y_test, random_forest_pred)
random_forest_precision = precision_score(y_test, random_forest_pred, average='macro')
random_forest_recall = recall_score(y_test, random_forest_pred, average='macro')
random_forest_f1 = f1_score(y_test, random_forest_pred, average='macro')
print("Random Forest Accuracy:", random_forest_accuracy)
print("confusion_matrix:", confusion_matrix(y_test,random_forest_pred))
print("precision_score:",random_forest_precision)
print("recall_score:",random_forest_recall)
print("f1_score:",random_forest_f1)
# Out:
# Random Forest Accuracy: 0.751275167785235
# confusion_matrix: [[5247 1849]
#  [1857 5947]]
# precision_score: 0.750712531894388
# recall_score: 0.7507378851188966
# f1_score: 0.7507249909714699

# %% [markdown]
# **SVM**

# %%
from sklearn.svm import SVC
svm = SVC()
svm.fit(X_train, y_train)
svm_pred = svm.predict(X_test)
svm_accuracy = accuracy_score(y_test, svm_pred)
svm_precision = precision_score(y_test, svm_pred, average='macro')
svm_recall = recall_score(y_test, svm_pred, average='macro')
svm_f1 = f1_score(y_test, svm_pred, average='macro')
print("SVM Accuracy:", svm_accuracy)
print("confusion_matrix:", confusion_matrix(y_test,svm_pred))
print("precision_score:",svm_precision)
print("recall_score:",svm_recall)
print("f1_score:",svm_f1)
# Out:
# SVM Accuracy: 0.523758389261745
# confusion_matrix: [[   0 7096]
#  [   0 7804]]
# precision_score: 0.2618791946308725
# recall_score: 0.5
# f1_score: 0.3437279774489077
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# **SCALING**
#
# *   STANDARD SCALER

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.fit_transform(X_test)

# %% [markdown]
# Checking randomForest classifier again after scaling

# %%
from sklearn.ensemble import RandomForestClassifier
random_forest = RandomForestClassifier()
random_forest.fit(X_train, y_train)
random_forest_pred = random_forest.predict(X_test)
random_forest_accuracy = accuracy_score(y_test, random_forest_pred)
random_forest_precision = precision_score(y_test, random_forest_pred, average='macro')
random_forest_recall = recall_score(y_test, random_forest_pred, average='macro')
random_forest_f1 = f1_score(y_test, random_forest_pred, average='macro')
print("Random Forest Accuracy:", random_forest_accuracy)
print("confusion_matrix:", confusion_matrix(y_test,random_forest_pred))
print("precision_score:",random_forest_precision)
print("recall_score:",random_forest_recall)
print("f1_score:",random_forest_f1)
# Out:
# Random Forest Accuracy: 0.7494630872483221
# confusion_matrix: [[5237 1859]
#  [1874 5930]]
# precision_score: 0.748897356571588
# recall_score: 0.7489440777631451
# f1_score: 0.7489199543225236

# %% [markdown]
# It is clear that scaling reduces th accuracy scores.So we choose Random forest classifier without scaling as our model

# %% [markdown]
# **Choosing RandomForest classifier as best model**

# %%
from sklearn.ensemble import RandomForestClassifier
random_forest = RandomForestClassifier()
random_forest.fit(X_train, y_train)
random_forest_pred = random_forest.predict(X_test)
random_forest_accuracy = accuracy_score(y_test, random_forest_pred)
random_forest_precision = precision_score(y_test, random_forest_pred, average='macro')
random_forest_recall = recall_score(y_test, random_forest_pred, average='macro')
random_forest_f1 = f1_score(y_test, random_forest_pred, average='macro')
print("Random Forest Accuracy:", random_forest_accuracy)
print("confusion_matrix:", confusion_matrix(y_test,random_forest_pred))
print("precision_score:",random_forest_precision)
print("recall_score:",random_forest_recall)
print("f1_score:",random_forest_f1)
# Out:
# Random Forest Accuracy: 0.7508724832214765
# confusion_matrix: [[5263 1833]
#  [1879 5925]]
# precision_score: 0.7503180969496694
# recall_score: 0.7504557472622659
# f1_score: 0.7503797370274936

# %% [markdown]
# **HYPERPARAMETER TUNING**

# %%
rf_clf = RandomForestClassifier(n_estimators=20,max_depth=20,criterion='entropy',min_samples_split=2)
rf_clf.fit(X_train,y_train)
y_pred = rf_clf.predict(X_test)
print('confusion_matrix',confusion_matrix(y_test,y_pred))
print('Accuracy',accuracy_score(y_test,y_pred))
print("precision_score:",precision_score(y_test,y_pred, average='macro'))
print("recall_score:",recall_score(y_test,y_pred, average='macro'))
print("f1_score:",f1_score(y_test,y_pred, average='macro'))
# Out:
# confusion_matrix [[5161 1935]
#  [1921 5883]]
# Accuracy 0.7412080536912752
# precision_score: 0.7406215925146562
# recall_score: 0.7405776718440577
# f1_score: 0.7405989748028518

# %% [markdown]
# **CHECKING FOR PREDICTION**

# %%
a=[31,1,19,0,5390,0,2,0,2.0,0,3,1,1,0.0,1,1,89,0,0,0,0,2]

# %%
random_forest.predict ([a])
if random_forest.predict ([a])==0:
  print("Left")
else:
  print("Stayed")
# Out:
# Stayed
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# WE GOT THE ATTRITION COLUMN PREDICTION AS "STAYED"

# %% [markdown]
# **MODEL SUCCESSFULL**
